# %%
from PIL import Image

# %%
 bob = Image.open('hh.jpg')
 bob
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x704 at 0x15EBF00D460>

# %%
bob.show()

# %%
bob.format
# Out:
# 'JPEG'

# %%
bob.size
# Out:
# (564, 704)

# %%
bob.mode
# Out:
# 'RGB'

# %%
bob.convert('L')               # BLACK & WHITE
# Out:
# <PIL.Image.Image image mode=L size=564x704 at 0x15EBE18A0D0>

# %%
bob1 = bob.convert('1')

# %%
bob1.save('burr.jpg','JPEG')

# %%
crop_box = (200,200,1200,900)
bob.crop(crop_box)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x700 at 0x15EBEF88310>
